# %% [markdown]
# <a href="https://colab.research.google.com/github/yach1603/DeepLearning/blob/main/Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls /content/drive/MyDrive/Colab_Notebooks
# Out:
# BNN.ipynb				       test.ipynb
# Deep-Learning-CNN.ipynb			       Untitled0.ipynb
# deep-learning-for-image-processing-master.zip  Untitled1.ipynb
# Deep-Learning.ipynb			       VAE_MNIST_BO.ipynb
# resnet.ipynb

# %%
# !unzip /content/drive/MyDrive/Colab_Notebooks/deep-learning-for-image-processing-master.zip

# %%
# !pip show torch
# Out:
# Name: torch
# Version: 1.12.1+cu113
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: typing-extensions
# Required-by: torchvision, torchtext, torchaudio, fastai

# %%
# !pip install -r /content/drive/MyDrive/deep-learning-for-image/pytorch_object_detection/mask_rcnn/requirements.txt

# %%
# !wget -P /content/drive/MyDrive/deep-learning-for-image/pytorch_object_detection/mask_rcnn http://host.robots.ox.ac.uk/pascal/VOC/voc2012/VOCtrainval_11-May-2012.tar
# Out:
# --2022-10-02 14:45:01--  http://host.robots.ox.ac.uk/pascal/VOC/voc2012/VOCtrainval_11-May-2012.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1999639040 (1.9G) [application/x-tar]
# Saving to: ‘/content/drive/MyDrive/deep-learning-for-image/pytorch_object_detection/mask_rcnn/VOCtrainval_11-May-2012.tar’
#
# VOCtrainval_11-May- 100%[===================>]   1.86G  28.0MB/s    in 71s
#
# 2022-10-02 14:46:11 (27.0 MB/s) - ‘/content/drive/MyDrive/deep-learning-for-image/pytorch_object_detection/mask_rcnn/VOCtrainval_11-May-2012.tar’ saved [1999639040/1999639040]

# %%
# !wget https://download.pytorch.org/models/maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth
# Out:
# --2022-10-03 15:55:41--  https://download.pytorch.org/models/maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth
# Resolving download.pytorch.org (download.pytorch.org)... 13.224.250.5, 13.224.250.7, 13.224.250.24, ...
# Connecting to download.pytorch.org (download.pytorch.org)|13.224.250.5|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 178090079 (170M) [binary/octet-stream]
# Saving to: ‘maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth’
#
# maskrcnn_resnet50_f 100%[===================>] 169.84M   303MB/s    in 0.6s
#
# 2022-10-03 15:55:41 (303 MB/s) - ‘maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth’ saved [178090079/178090079]

# %%
# !tar -xvf /content/drive/MyDrive/deep-learning-for-image/data_set/VOCtrainval_11-May-2012.tar
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# VOCdevkit/VOC2012/SegmentationClass/2008_001874.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001876.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001882.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001885.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001895.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001896.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001926.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001966.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001971.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001992.png
# VOCdevkit/VOC2012/SegmentationClass/2008_001997.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002032.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002043.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002064.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002066.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002067.png
# VOCdevkit/VOC2012/SegmentationClass/2008_002073.png
# ...

# %%
# !nvidia-smi
# Out:
# Mon Oct  3 15:51:58 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !cp /content/maskrcnn_resnet50_fpn_coco.pth /content/drive/MyDrive/deep-learning-for-image/pytorch_object_detection/mask_rcnn/

# %%
# !cp -r /content/drive/MyDrive/deep-learning-for-image/data_set/VOCdevkit /content
# Out:
# ^C

# %%
# !rm -rf /content/mask_rcnn

# %%
# !python train.py
# Out:
# Namespace(amp=True, aspect_ratio_group_factor=3, batch_size=2, data_path='./VOCdevkit', device='cuda:0', epochs=10, lr=0.002, lr_gamma=0.1, lr_steps=[5], momentum=0.9, num_classes=20, output_dir='/content/drive/MyDrive/deep-learning-for-image/pytorch_object_detection/mask_rcnn/save_weights', pretrain=True, resume='', start_epoch=0, weight_decay=0.0001)
# Using cuda device training.
# ...
# creating index...
# index created!
# Using [0, 0.5, 0.6299605249474366, 0.7937005259840997, 1.0, 1.2599210498948732, 1.5874010519681994, 2.0, inf] as bins for aspect ratio quantization
# Count of instances per bin: [   1  225   34   68 1077   48   10]
# Using 2 dataloader workers
# ...
# creating index...
# index created!
# _IncompatibleKeys(missing_keys=[], unexpected_keys=['fc.weight', 'fc.bias'])
# ...

# %%
# !python predict.py
# Out:
# using cuda:0 device.
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# inference+NMS time: 0.11717653274536133
# Figure(640x480)

# %%
# !python predict.py
# Out:
# using cuda:0 device.
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# inference+NMS time: 0.11656832695007324
# Figure(640x480)

# %%
# !cp -r /content/drive/MyDrive/deep-learning-for-image/pytorch_object_detection/mask_rcnn/* /content/
